# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from yahoo_fin.stock_info import *
from functools import reduce
import yfinance as yf
import datetime
import pandas_datareader.data as pdr
from pykrx import stock
import time

# %%
yf.pdr_override()

start_date = '01-09-2020'
end_date = '15-07-2021'

start = datetime.datetime.strptime(start_date, '%d-%m-%Y')
end = datetime.datetime.strptime(end_date, '%d-%m-%Y')

mrna = pdr.get_data_yahoo('mrna', data_source='yahoo', start=start, end=end)
nvda = pdr.get_data_yahoo('nvda', data_source='yahoo', start=start, end=end)
amzn = pdr.get_data_yahoo('amzn', data_source='yahoo', start=start, end=end)
arvl = pdr.get_data_yahoo('arvl', data_source='yahoo', start=start, end=end)

mrna['date'] = mrna.index
mrna = mrna.reset_index(drop=True)
mrna['symbol'] = 'MRNA'

nvda['date'] = nvda.index
nvda = nvda.reset_index(drop=True)
nvda['symbol'] = 'NVDA'

amzn['date'] = amzn.index
amzn = amzn.reset_index(drop=True)
amzn['symbol'] = 'AMZN'

arvl['date'] = arvl.index
arvl = arvl.reset_index(drop=True)
arvl['symbol'] = 'ARVL'

data = pd.concat([mrna, nvda, amzn, arvl])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data=data[['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'symbol']]

data.to_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data.csv', index=False)

# %%
data=pd.read_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data.csv')
data = data.drop(data.columns[0], axis=1)
data
# Out:
#            date       Open       High        Low      Close  Adj Close  \
# 0    2020-08-31  67.139999  67.199997  62.540001  64.889999  64.889999
# 1    2020-09-01  63.540001  64.500000  62.500000  63.320000  63.320000
# 2    2020-09-02  62.840000  64.889999  61.381001  64.720001  64.720001
# 3    2020-09-03  65.650002  69.349998  64.300003  64.839996  64.839996
# 4    2020-09-04  64.989998  65.000000  59.009998  62.599998  62.599998
# ..          ...        ...        ...        ...        ...        ...
# 870  2021-07-08  14.300000  15.470000  14.280000  15.400000  15.400000
# 871  2021-07-09  15.380000  15.860000  15.120000  15.550000  15.550000
# 872  2021-07-12  15.550000  15.750000  14.920000  15.000000  15.000000
# 873  2021-07-13  14.860000  14.930000  14.220000  14.290000  14.290000
# 874  2021-07-14  14.510000  14.580000  13.310000  13.370000  13.370000
#
#        Volume symbol
# 0    15271800   MRNA
# 1     8183600   MRNA
# 2     9874600   MRNA
# 3    14307300   MRNA
# ...

# %%
data=pd.read_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data.csv')
data
# Out:
#            date       Open       High        Low      Close  Adj Close  \
# 0    2020-08-31  67.139999  67.199997  62.540001  64.889999  64.889999
# 1    2020-09-01  63.540001  64.500000  62.500000  63.320000  63.320000
# 2    2020-09-02  62.840000  64.889999  61.381001  64.720001  64.720001
# 3    2020-09-03  65.650002  69.349998  64.300003  64.839996  64.839996
# 4    2020-09-04  64.989998  65.000000  59.009998  62.599998  62.599998
# ..          ...        ...        ...        ...        ...        ...
# 870  2021-07-08  14.300000  15.470000  14.280000  15.400000  15.400000
# 871  2021-07-09  15.380000  15.860000  15.120000  15.550000  15.550000
# 872  2021-07-12  15.550000  15.750000  14.920000  15.000000  15.000000
# 873  2021-07-13  14.860000  14.930000  14.220000  14.290000  14.290000
# 874  2021-07-14  14.510000  14.580000  13.310000  13.370000  13.370000
#
#        Volume symbol
# 0    15271800   MRNA
# 1     8183600   MRNA
# 2     9874600   MRNA
# 3    14307300   MRNA
# ...

# %%
yf.pdr_override()

tickers=['MRNA', 'NVDA', 'AMZN', 'ARVL']

start_date = '01-09-2020'
end_date = '15-07-2021'

start = datetime.datetime.strptime(start_date, '%d-%m-%Y')
end = datetime.datetime.strptime(end_date, '%d-%m-%Y')

temp_data_set=[]
for ticker in tickers :
    temp_data = pdr.get_data_yahoo(ticker , data_source='yahoo', start=start, end=end)
    temp_data['date'] = temp_data.index
    temp_data = temp_data.reset_index(drop=True)
    temp_data['symbol']=ticker
    temp_data_set.append(temp_data)
data = pd.concat(temp_data_set)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#           Open       High        Low      Close  Adj Close    Volume  \
# 0    67.139999  67.199997  62.540001  64.889999  64.889999  15271800
# 1    63.540001  64.500000  62.500000  63.320000  63.320000   8183600
# 2    62.840000  64.889999  61.381001  64.720001  64.720001   9874600
# 3    65.650002  69.349998  64.300003  64.839996  64.839996  14307300
# 4    64.989998  65.000000  59.009998  62.599998  62.599998  11653300
# ..         ...        ...        ...        ...        ...       ...
# 213  14.300000  15.470000  14.280000  15.400000  15.400000   2640300
# 214  15.380000  15.860000  15.120000  15.550000  15.550000   1954300
# 215  15.550000  15.750000  14.920000  15.000000  15.000000   1510600
# ...

# %%
from pykrx import stock
import time

s = time.time()

tickers = stock.get_market_ticker_list("20190225", market="KOSPI")  # KOSPI / KOSDAQ / KONEX / ALL / default = KOSPI
print(tickers[:10]) 
start_date = '18-07-2020'
end_date = '18-07-2021'

start = datetime.datetime.strptime(start_date, '%d-%m-%Y')
end = datetime.datetime.strptime(end_date, '%d-%m-%Y')

temp_data_set=[]
num=0
for ticker in tickers :
    temp_data = pdr.get_data_yahoo('{}.ks'.format(ticker) , data_source='yahoo', start=start, end=end)
    temp_data['date'] = temp_data.index
    temp_data = temp_data.reset_index(drop=True)
    temp_data['symbol']=ticker
    temp_data_set.append(temp_data)
    num+=1
    print('{} % completed'.format(int(num/921)))
data = pd.concat(temp_data_set)
e = time.time()
print(s-e)
# Out:
# ['095570', '068400', '006840', '027410', '282330', '138930', '001460', '001465', '001040', '079160']
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
data.to_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data_KOSPI.csv')

# %%
st='95570'
print('{:06d}'.format(int(st)))
# Out:
# 095570

# %%
tickers[-1]
# Out:
# '003280'

# %%
s = time.time()

start_date = '01-01-2005'
end_date = '18-07-2021'

start = datetime.datetime.strptime(start_date, '%d-%m-%Y')
end = datetime.datetime.strptime(end_date, '%d-%m-%Y')

tickers = stock.get_market_ticker_list("20210718", market="KOSPI")  # KOSPI / KOSDAQ / KONEX / ALL / default = KOSPI
tickers=['{}.ks'.format(ticker) for ticker in tickers]

data=pdr.get_data_yahoo(tickers , data_source='yahoo', start=start, end=end)

data=data.stack()
data=data.reset_index()
data=data.rename(columns={'level_1':'symbol'})
data=data.rename(columns={'Date':'date'})

e = time.time()
print(e-s)
# Out:
# [*********************100%***********************]  929 of 929 completed
# 199.5595932006836

# %%
data.to_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data_KOSPI.csv')

# %%
data=pd.read_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data_KOSPI.csv', index_col=0)
data.head()
# Out:
# c:\users\ajcltm\desktop\python\pythonproject\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          date     symbol     Adj Close         Close          High  \
# 0  2005-01-04  000020.KS   1518.722290   1748.000000   1756.000000
# 1  2005-01-04  000040.KS   2340.000000   2340.000000   2430.000000
# 2  2005-01-04  000050.KS   2963.146484   3734.850098   3939.389893
# 3  2005-01-04  000060.KS    437.496582   1530.209961   1530.209961
# 4  2005-01-04  000100.KS  10011.900391  10011.900391  10140.599609
#
#            Low         Open    Volume
# 0  1722.000000  1756.000000   72000.0
# 1  2310.000000  2400.000000  419300.0
# 2  3734.850098  3939.389893    6600.0
# 3  1503.829956  1517.020020  169427.0
# 4  9918.339844  9988.519531   95757.0

# %%
len(data)
# Out:
# 3039114

# %%
yf.pdr_override()

start_date = '23-06-2021'
end_date = '28-06-2021'

start = datetime.datetime.strptime(start_date, '%d-%m-%Y')
end = datetime.datetime.strptime(end_date, '%d-%m-%Y')

tickers = stock.get_market_ticker_list("20210718", market="KOSPI")  # KOSPI / KOSDAQ / KONEX / ALL / default = KOSPI
tickers=['{}.ks'.format(ticker) for ticker in tickers]

data=pdr.get_data_yahoo(tickers , data_source='yahoo', start=start, end=end)

data=data.stack()
data=data.reset_index()
data=data.rename(columns={'level_1':'symbol'})
data=data.rename(columns={'Date':'date'})
# Out:
# [*********************100%***********************]  929 of 929 completed
#
# 621 Failed downloads:
# - 00104K.KS: No data found for this date range, symbol may be delisted
# - 051915.KS: No data found for this date range, symbol may be delisted
# - 000390.KS: No data found for this date range, symbol may be delisted
# - 006280.KS: No data found for this date range, symbol may be delisted
# - 004250.KS: No data found for this date range, symbol may be delisted
# - 024110.KS: No data found for this date range, symbol may be delisted
# - 153360.KS: No data found for this date range, symbol may be delisted
# - 004020.KS: No data found for this date range, symbol may be delisted
# - 005110.KS: No data found for this date range, symbol may be delisted
# - 003535.KS: No data found for this date range, symbol may be delisted
# - 000970.KS: No data found for this date range, symbol may be delisted
# - 120115.KS: No data found for this date range, symbol may be delisted
# ...

# %%
yf.pdr_override()

start_date = '23-06-2021'
end_date = '23-06-2021'

start = datetime.datetime.strptime(start_date, '%d-%m-%Y')
end = datetime.datetime.strptime(end_date, '%d-%m-%Y')

# tickers = stock.get_market_ticker_list("20210718", market="KOSPI")  # KOSPI / KOSDAQ / KONEX / ALL / default = KOSPI
# tickers=['{}.ks'.format(ticker) for ticker in tickers]

data=pdr.get_data_yahoo('NVDA' , data_source='yahoo', start=start, end=end)

data=data.stack()
data=data.reset_index()
data=data.rename(columns={'level_1':'symbol'})
data=data.rename(columns={'Date':'date'})
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tickers = stock.get_market_ticker_list("20210718", market="KOSPI")  # KOSPI / KOSDAQ / KONEX / ALL / default = KOSPI
dfs=[]
for ticker in tickers :
    temp = stock.get_market_ohlcv_by_date("20210623", "20210628", ticker)
    temp = temp.reset_index()
    temp = temp.rename(columns={'날짜':'date', '시가': 'Open', '고가':'High', '저가':'Low', '종가':'Close', '거래량': 'Volume'})
    temp['Adj Close'] = temp['Close']
    temp['symbol'] = '{}.KS'.format(ticker)
    temp = temp[['date', 'symbol', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']]
    dfs.append(temp)
data_ = pd.concat(dfs)

# %%
data_
# Out:
#          date     symbol  Adj Close  Close   High    Low   Open  Volume
# 0  2021-06-23  095570.KS       5870   5870   6020   5850   5980   96991
# 1  2021-06-24  095570.KS       5910   5910   5910   5780   5800   45074
# 2  2021-06-25  095570.KS       5970   5970   6040   5870   5870   65291
# 3  2021-06-28  095570.KS       6110   6110   6140   5880   5970   94601
# 0  2021-06-23  006840.KS      32800  32800  33600  32000  33550   49457
# ..        ...        ...        ...    ...    ...    ...    ...     ...
# 3  2021-06-28  000545.KS      11400  11400  11600  11200  11200    9807
# 0  2021-06-23  003280.KS       1035   1035      0      0      0       0
# 1  2021-06-24  003280.KS       1035   1035      0      0      0       0
# 2  2021-06-25  003280.KS       1035   1035      0      0      0       0
# 3  2021-06-28  003280.KS       1035   1035      0      0      0       0
#
# [3712 rows x 8 columns]

# %%
data = pd.read_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data_KOSPI.csv', index_col=0)
# Out:
# c:\users\ajcltm\desktop\python\pythonproject\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-77995c621f61> in <module>
#       1 data = pd.read_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data_KOSPI.csv', index_col=0)
# ----> 2 data['date']==datetime(2021,6,23)
#
# TypeError: 'module' object is not callable

# %%
data['date'] = pd.to_datetime(data['date'])
del_date=[23,24,25,28]
for d in del_date:
    idex = data[data['date']==datetime.datetime(2021,6,d)].index
    data=data.drop(idex)

# %%
data[data['date']==datetime.datetime(2021,6,29)]
# Out:
#               date     symbol  Adj Close     Close      High       Low  \
# 3026396 2021-06-29  000020.KS    15650.0   15650.0   16100.0   15600.0
# 3026397 2021-06-29  000040.KS     1255.0    1255.0    1260.0    1215.0
# 3026398 2021-06-29  000050.KS    14200.0   14200.0   14500.0   14150.0
# 3026399 2021-06-29  000060.KS    20000.0   20000.0   20000.0   19400.0
# 3026400 2021-06-29  000070.KS   110500.0  110500.0  112000.0  109000.0
# ...            ...        ...        ...       ...       ...       ...
# 3027301 2021-06-29  383220.KS   562000.0  562000.0  567000.0  542000.0
# 3027302 2021-06-29  383800.KS    11200.0   11200.0   11400.0   11200.0
# 3027303 2021-06-29  38380K.KS    20150.0   20150.0   20500.0   20150.0
# 3027304 2021-06-29  900140.KS     3750.0    3750.0    3795.0    3730.0
# 3027305 2021-06-29  950210.KS    33050.0   33050.0   33500.0   32050.0
#
#              Open     Volume
# 3026396   15800.0   413276.0
# 3026397    1220.0  1039051.0
# ...

# %%
data_fixed = data.append(data_)

# %%
data_fixed['date'] = pd.to_datetime(data_fixed['date'])

# %%
data_fixed
# Out:
#          date     symbol     Adj Close         Close          High  \
# 0  2005-01-04  000020.KS   1518.722290   1748.000000   1756.000000
# 1  2005-01-04  000040.KS   2340.000000   2340.000000   2430.000000
# 2  2005-01-04  000050.KS   2963.146484   3734.850098   3939.389893
# 3  2005-01-04  000060.KS    437.496582   1530.209961   1530.209961
# 4  2005-01-04  000100.KS  10011.900391  10011.900391  10140.599609
# ..        ...        ...           ...           ...           ...
# 3  2021-06-28  000545.KS  11400.000000  11400.000000  11600.000000
# 0  2021-06-23  003280.KS   1035.000000   1035.000000      0.000000
# 1  2021-06-24  003280.KS   1035.000000   1035.000000      0.000000
# 2  2021-06-25  003280.KS   1035.000000   1035.000000      0.000000
# 3  2021-06-28  003280.KS   1035.000000   1035.000000      0.000000
#
#              Low          Open    Volume
# 0    1722.000000   1756.000000   72000.0
# 1    2310.000000   2400.000000  419300.0
# ...

# %%
data_fixed[data_fixed['date']==datetime.datetime(2021,6,21)]
# Out:
#               date     symbol  Adj Close     Close      High       Low  \
# 3024572 2021-06-21  000020.KS    14500.0   14500.0   14600.0   14350.0
# 3024573 2021-06-21  000040.KS     1230.0    1230.0    1265.0    1220.0
# 3024574 2021-06-21  000050.KS    14300.0   14300.0   14700.0   14250.0
# 3024575 2021-06-21  000060.KS    18400.0   18400.0   18500.0   17900.0
# 3024576 2021-06-21  000070.KS   104000.0  104000.0  106500.0  103500.0
# ...            ...        ...        ...       ...       ...       ...
# 3025476 2021-06-21  383220.KS   525000.0  525000.0  544000.0  511000.0
# 3025477 2021-06-21  383800.KS    11200.0   11200.0   11350.0   11100.0
# 3025478 2021-06-21  38380K.KS    21000.0   21000.0   21200.0   20900.0
# 3025479 2021-06-21  900140.KS     3765.0    3765.0    3805.0    3740.0
# 3025480 2021-06-21  950210.KS    28600.0   28600.0   29250.0   28600.0
#
#              Open    Volume
# 3024572   14400.0  123450.0
# 3024573    1260.0  834196.0
# ...

# %%
data_fixed.to_csv('C:/Users/ajcltm/PycharmProjects/BackTesting/data/stock_price_data_KOSPI_fixed.csv')
